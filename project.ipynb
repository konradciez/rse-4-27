# %% [raw]
# ---
# title: "Tytuł"
# author: "Konrad"
# date: "2026-04-27"
# execute:
#   enabled: true
# ---

# %%
import numpy as np
x = np.atan(1) * 4
print(x)
# Out:
# 3.141592653589793

# %% [markdown]
# The value of $\pi$ is `{python} f"{x:.4g}"`
#
# Yay!
